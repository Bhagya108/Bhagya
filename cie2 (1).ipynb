# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('/content/tips0.csv')
df.head()
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    object
#  1   tip         244 non-null    object
#  2   sex         242 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        243 non-null    object
# dtypes: object(7)
# memory usage: 13.5+ KB
#        total_bill  tip   sex smoker  day    time size
# count         244  244   242    244  244     244  243
# unique        227  122     2      3    4       2    7
# top          Null    2  Male     No  Sat  Dinner    2
# freq            3   33   156    150   87     176  154

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           2
# smoker        0
# day           0
# time          0
# size          1
# dtype: int64

# %%
df.fillna(0)
# Out:
#     total_bill   tip     sex smoker   day    time size
# 0        16.99  1.01  Female     No   Sun  Dinner    2
# 1        10.34  1.66    Male     No   Sun  Dinner    3
# 2        21.01   3.5    Male     No   Sun  Dinner    3
# 3        23.68  3.31    Male     No   Sun  Dinner    2
# 4        24.59  3.61  Female     No   Sun  Dinner    4
# ..         ...   ...     ...    ...   ...     ...  ...
# 239      29.03  5.92    Male     No   Sat  Dinner    3
# 240      27.18     2  Female    Yes   Sat  Dinner    2
# 241      22.67     2    Male    Yes   Sat  Dinner    2
# 242      17.82  1.75    Male     No   Sat  Dinner    2
# 243      18.78     3  Female     No  Thur  Dinner    2
#
# [244 rows x 7 columns]

# %%
x=df['total_bill']
y=df['tip']
plt.scatter(df['total_bill'],df['tip'],color='orange')
plt.title("total_bill vs tips")
plt.xlabel("total_bill")
plt.ylabel("count")
plt.grid()
plt.show()

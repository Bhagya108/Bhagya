# %%
import spacy
from nltk import ngrams
nlp=spacy.load("en_core_web_sm")
doc=nlp("AI is simulation of human intelligence by machine.It includes expects system NLP speech recoginition and machine vision.")
bigrams=ngrams(doc,2)
print(list(bigrams))
# Out:
# [(AI, is), (is, simulation), (simulation, of), (of, human), (human, intelligence), (intelligence, by), (by, machine), (machine, .), (., It), (It, includes), (includes, expects), (expects, system), (system, NLP), (NLP, speech), (speech, recoginition), (recoginition, and), (and, machine), (machine, vision), (vision, .)]

# %% [markdown]
# ## **Trigrams**

# %%
import spacy
from nltk import ngrams
nlp=spacy.load("en_core_web_sm")
doc=nlp("AI is simulation of human intelligence by machine.It includes expects system NLP speech recoginition and machine vision.")
trigrams=ngrams(doc,3)
print(list(trigrams))
# Out:
# [(AI, is, simulation), (is, simulation, of), (simulation, of, human), (of, human, intelligence), (human, intelligence, by), (intelligence, by, machine), (by, machine, .), (machine, ., It), (., It, includes), (It, includes, expects), (includes, expects, system), (expects, system, NLP), (system, NLP, speech), (NLP, speech, recoginition), (speech, recoginition, and), (recoginition, and, machine), (and, machine, vision), (machine, vision, .)]
